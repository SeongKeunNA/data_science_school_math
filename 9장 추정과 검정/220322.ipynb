# %% [markdown]
# # 9.1 확률분포의 추정

# %% [markdown]
# ### 연습문제 9.1.1

# %%
from sklearn.datasets import load_boston
boston = load_boston()
dfX = pd.DataFrame(boston.data, columns=boston.feature_names)
dfy = pd.DataFrame(boston.target, columns = ['MEDV'])
df = pd.concat([dfX, dfy], axis=1)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df['CRIM'].hist(bins=100)
plt.title('CRIM값의 분포')
plt.show()

# %%
df['ZN'].hist(bins=100)
plt.title('ZN값의 분포')
plt.show()

# %%
df['INDUS'].hist(bins=100)
plt.title('INDUS값의 분포')
plt.show()

# %%
df['CHAS'].hist(bins=100)
plt.title('CHAS값의 분포')
plt.show()

# %%
np.log(df['NOX']).hist(bins=100)
plt.title('NOX값의 로그값 분포')
plt.show()

# %%
df['RM'].hist(bins=100)
plt.title('RM값의 분포')
plt.show()

# %%
df['AGE'].hist(bins=100)
plt.title('AGE값을 100으로 나눈 값의 분포')
plt.show()

# %%
np.log(df['DIS']).hist(bins=100)
plt.title('DIS값의 로그값 분포')
plt.show()

# %%
df['RAD'].hist(bins=100)
plt.title('RAD값의 분포')
plt.show()

# %%
df['TAX'].hist(bins=100)
plt.title('TAX값의 분포')
plt.show()

# %%
df['PTRATIO'].hist(bins=100)
plt.title('PTRATIO값의 분포')
plt.show()

# %%
df['B'].hist(bins=100)
plt.title('B값의 분포')
plt.show()

# %%
np.log(df['LSTAT']).hist(bins=100)
plt.title('LSTST값의 분포')
plt.show()

# %%
np.log(df['MEDV']).hist(bins=100)
plt.title('MEDV값의 로그값 분포')
plt.show()

# %% [markdown]
# ### 연습문제 9.1.2

# %%
sns.distplot(df['CRIM'], kde = False, fit = sp.stats.expon)
plt.title('CRIM값의 분포')
plt.show()

# %%
sns.distplot(np.log(df['NOX']), kde = False, fit = sp.stats.norm)
plt.title('NOX값의 분포')
plt.show()

# %%
sns.distplot(df['RM'], kde = False, fit = sp.stats.norm)
plt.title('RM값의 분포')
plt.show()

# %%
sns.distplot(np.log(df['DIS']), kde = False, fit = sp.stats.norm)
plt.title('DIS값의 로그값 분포')
plt.show()

# %%
sns.distplot(df['RAD'], kde = False, fit = sp.stats.norm)
plt.title('RAD값의 분포')
plt.show()

# %%
sns.distplot(df['TAX'], kde = False, fit = sp.stats.norm)
plt.title('TAX값의 분포')
plt.show()

# %%
sns.distplot(np.log(df['LSTAT']), kde = False, fit = sp.stats.norm)
plt.title('LSTAT값의 로그값 분포')
plt.show()

# %%
sns.distplot(np.log(df['MEDV']), kde = False, fit = sp.stats.norm)
plt.title('MEDV값의 로그값 분포')
plt.show()

# %% [markdown]
# # 9.2 최대가능도 추정법

# %% [markdown]
# ### 연습문제 9.2.1

# %%
arg max_mu L(mu;{xi})
arg max_mu L(mu;{1, 0, 1, 1})
arg max_mu p(1;mu)p(0;mu)p(1;mu)p(1;mu)
arg max_mu mu^3 * (1-mu)
arg max_mu mu^3 - mu^4
mu = 3/4

# %% [markdown]
# ### 연습문제 9.2.2

# %%
arg max_mu1,mu2,mu3,mu4 log(L(mu1,mu2,mu3,mu4;{1,1,2,2,3,4,4,4}))
arg max_mu1,mu2,mu3,mu4 log(p(1;mu1,mu2,mu3,mu4)^2 p(2;mu1,mu2,mu3,mu4)^2 p(3;mu1,mu2,mu3,mu4) p(4;mu1,mu2,mu3,mu4)^3)
arg max_mu1,mu2,mu3,mu4 log ( (mu1^2) * (mu2^2) * (mu3) * (mu4*3) )
arg max_mu1,mu2,mu3,mu4 2log(mu1) + 2log(mu2) + log(mu3) + 3log(mu4)
, u1 + u2 + u3 + u4 - 1 = 0
J = 2log(mu1) + 2log(mu2) + log(mu3) + 3log(mu4) + λ (u1 + u2 + u3 + u4 - 1)
∂J / ∂mu1 = 2 / mu1 +  λ = 0
∂J / ∂mu2 = 2 / mu2+  λ = 0
∂J / ∂mu3 = mu3+  λ = 0
∂J / ∂mu4 = 3 / mu4 +  λ = 0
∂J / ∂λ  = u1 + u2 + u3 + u4 - 1

mu1, mu2 ,mu3, mu4 = 1/4 ,1/4, 1/8, 3/8
